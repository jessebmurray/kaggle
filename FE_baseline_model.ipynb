# %% [markdown]
# # Feature Engineering
# ## Baseline model

# %%
import pandas as pd
ks = pd.read_csv('../data/ks-projects-201801.csv', parse_dates=['deadline', 'launched'])

# %%
ks.shape
# Out:
# (378661, 15)

# %%
ks.head(10)
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
# 5  1000014025                               Monarch Espresso Bar
# 6  1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7  1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8  1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9   100004195  STUDIO IN THE SKY - A Documentary Feature Film...
#
#          category main_category currency   deadline      goal  \
# 0          Poetry    Publishing      GBP 2015-10-09    1000.0
# 1  Narrative Film  Film & Video      USD 2017-11-01   30000.0
# 2  Narrative Film  Film & Video      USD 2013-02-26   45000.0
# 3           Music         Music      USD 2012-04-16    5000.0
# 4    Film & Video  Film & Video      USD 2015-08-29   19500.0
# 5     Restaurants          Food      USD 2016-04-01   50000.0
# 6            Food          Food      USD 2014-12-21    1000.0
# 7          Drinks          Food      USD 2016-03-17   25000.0
# 8  Product Design        Design      USD 2014-05-29  125000.0
# 9     Documentary  Film & Video      USD 2014-08-10   65000.0
#
#              launched   pledged       state  backers country  usd pledged  \
# 0 2015-08-11 12:12:28      0.00      failed        0      GB         0.00
# 1 2017-09-02 04:43:57   2421.00      failed       15      US       100.00
# 2 2013-01-12 00:20:50    220.00      failed        3      US       220.00
# 3 2012-03-17 03:24:11      1.00      failed        1      US         1.00
# 4 2015-07-04 08:35:03   1283.00    canceled       14      US      1283.00
# 5 2016-02-26 13:38:27  52375.00  successful      224      US     52375.00
# 6 2014-12-01 18:30:44   1205.00  successful       16      US      1205.00
# 7 2016-02-01 20:05:12    453.00      failed       40      US       453.00
# 8 2014-04-24 18:14:43   8233.00    canceled       58      US      8233.00
# 9 2014-07-11 21:55:48   6240.57    canceled       43      US      6240.57
#
#    usd_pledged_real  usd_goal_real
# 0              0.00        1533.95
# 1           2421.00       30000.00
# 2            220.00       45000.00
# 3              1.00        5000.00
# 4           1283.00       19500.00
# 5          52375.00       50000.00
# 6           1205.00        1000.00
# 7            453.00       25000.00
# 8           8233.00      125000.00
# 9           6240.57       65000.00

# %% [markdown]
# We want to predict whether a kickstarter project will succeed.

# %%
ks.state.unique()
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'undefined',
#        'suspended'], dtype=object)

# %%
pd.unique(ks.state)
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'undefined',
#        'suspended'], dtype=object)

# %%
ks.state.value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
ks.groupby('state')['ID'].count()
# Out:
# state
# canceled       38779
# failed        197719
# live            2799
# successful    133956
# suspended       1846
# undefined       3562
# Name: ID, dtype: int64

# %% [markdown]
# We can drop 'live' projects, count 'successful' states as `outcome = 1`, every other state can be `outcome = 0`

# %%
# ks = ks.loc[ks.state != 'live']

ks = ks.query('state != "live"')

# %%
ks.state.unique()
# Out:
# array(['failed', 'canceled', 'successful', 'undefined', 'suspended'],
#       dtype=object)

# %%
# ks['outcome'] = ks.state.map(lambda x: 1 if x == 'successful' else 0)

ks = ks.assign(outcome=(ks['state'] == 'successful').astype(int))

# %% [markdown]
# The `launched` feature can be converted into categorical features, with the date-time attribute.

# %%
ks.launched
# Out:
# 0        2015-08-11 12:12:28
# 1        2017-09-02 04:43:57
# 2        2013-01-12 00:20:50
# 3        2012-03-17 03:24:11
# 4        2015-07-04 08:35:03
#                  ...
# 378656   2014-09-17 02:35:30
# 378657   2011-06-22 03:35:14
# 378658   2010-07-01 19:40:30
# 378659   2016-01-13 18:13:53
# 378660   2011-07-19 09:07:47
# Name: launched, Length: 375862, dtype: datetime64[ns]

# %%
ks = ks.assign(hour=ks.launched.dt.hour, day=ks.launched.dt.day, 
          month=ks.launched.dt.month, year=ks.launched.dt.year)

# %%
ks.dtypes
# Out:
# ID                           int64
# name                        object
# category                    object
# main_category               object
# currency                    object
# deadline            datetime64[ns]
# goal                       float64
# launched            datetime64[ns]
# pledged                    float64
# state                       object
# backers                      int64
# country                     object
# usd pledged                float64
# usd_pledged_real           float64
# usd_goal_real              float64
# outcome                      int64
# hour                         int64
# day                          int64
# month                        int64
# year                         int64
# dtype: object

# %% [markdown]
# ### Preparing categorical variables

# %%
cat_features = ['category', 'currency', 'country']
for col in cat_features:
    print(col.upper(), ks[col].nunique(), sep=', Cardinality: ')
    print(ks[col].value_counts())
    print()
    print()
# Out:
# CATEGORY, Cardinality: 159
# Product Design     22077
# Documentary        16082
# Music              15647
# Tabletop Games     14072
# Shorts             12311
#                    ...
# Residencies           69
# Letterpress           48
# Chiptune              35
# Literary Spaces       23
# Taxidermy             13
# Name: category, Length: 159, dtype: int64
#
#
# CURRENCY, Cardinality: 14
# USD    293624
# GBP     33853
# EUR     17076
# CAD     14830
# AUD      7880
# SEK      1768
# MXN      1645
# NZD      1464
# DKK      1113
# CHF       754
# NOK       714
# HKD       583
# SGD       527
# JPY        31
# Name: currency, dtype: int64
#
#
# COUNTRY, Cardinality: 23
# US      290887
# GB       33393
# CA       14624
# AU        7769
# DE        4096
# N,0"      3796
# FR        2887
# NL        2833
# IT        2802
# ES        2224
# SE        1737
# MX        1645
# NZ        1436
# DK        1097
# IE         800
# CH         747
# NO         700
# BE         605
# HK         583
# AT         582
# SG         527
# LU          61
# JP          31
# Name: country, dtype: int64

# %% [markdown]
# The cardinality of each of these columns is rather high, so we will label encode them, rather than one-hot encode them. `Sklearn` provides a label encoder.

# %%
from sklearn.preprocessing import LabelEncoder

cat_features = ['category', 'currency', 'country']
encoder = LabelEncoder()

# Apply the label encoder to each column
encoded = ks[cat_features].apply(encoder.fit_transform)

# %%
encoded.head()
# Out:
#    category  currency  country
# 0       108         5        9
# 1        93        13       22
# 2        93        13       22
# 3        90        13       22
# 4        55        13       22

# %% [markdown]
# If need be, we can get the inverse transformation.

# %%
encoder.inverse_transform(encoded.country)
# Out:
# array(['GB', 'US', 'US', ..., 'US', 'US', 'US'], dtype=object)

# %% [markdown]
# However, the `encoder` has 'forgotten' the previous columns' transformations. We could solve this problem in the future by looping through and creating a separate encoder for each of the columns in `cat_features`.

# %%
encoder.classes_
# Out:
# array(['AT', 'AU', 'BE', 'CA', 'CH', 'DE', 'DK', 'ES', 'FR', 'GB', 'HK',
#        'IE', 'IT', 'JP', 'LU', 'MX', 'N,0"', 'NL', 'NO', 'NZ', 'SE', 'SG',
#        'US'], dtype=object)

# %% [markdown]
# We can join the label encoded categorical features with some of the features in the model. They already have the same index.

# %%
data = ks[['goal', 'hour', 'day', 'month', 'year', 'outcome']].join(encoded)

# %%
data.head()
# Out:
#       goal  hour  day  month  year  outcome  category  currency  country
# 0   1000.0    12   11      8  2015        0       108         5        9
# 1  30000.0     4    2      9  2017        0        93        13       22
# 2  45000.0     0   12      1  2013        0        93        13       22
# 3   5000.0     3   17      3  2012        0        90        13       22
# 4  19500.0     8    4      7  2015        0        55        13       22

# %%
ks.shape
# Out:
# (375862, 20)

# %% [markdown]
# We can use 10% of the data for validation, 10% for testing, and 80% for testing. In general, we'll want to shuffle our dataset, incase the data is listed in an orderly way.

# %%
# Shuffle
# data.sample(frac=1).reset_index(drop=True)

# %%
valid_fraction = 0.1
valid_size = int(len(data) * valid_fraction)
train = data[:-2 * valid_size]
valid = data[-2 * valid_size:-valid_size]
test = data[-valid_size:]

# %% [markdown]
# We also want to make sure that each data set has the same proportion of target classes.

# %%
for each in [train, valid, test]:
    print('Outcome fraction = {:.4f}'.format(each.outcome.mean()))
# Out:
# Outcome fraction = 0.3570
# Outcome fraction = 0.3539
# Outcome fraction = 0.3542

# %% [markdown]
# We could have also used this built in `Sklearn` object.

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %% [markdown]
# We can use a 'fast, distributed, high performance gradient boosting' model: LightGBM.
# https://github.com/microsoft/LightGBM

# %%
# %%time
import lightgbm as lgb

feature_cols = train.columns.drop('outcome')

dtrain = lgb.Dataset(train[feature_cols], label=train['outcome'])

dvalid = lgb.Dataset(valid[feature_cols], label=valid['outcome'])

param = {'num_leaves': 64, 'objective': 'binary'}
param['metric'] = 'auc'
num_round = 1000
bst = lgb.train(param, dtrain, num_round, valid_sets=[dvalid], 
            early_stopping_rounds=10, verbose_eval=True)
# Out:
# [1]	valid_0's auc: 0.694192
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's auc: 0.697026
# [3]	valid_0's auc: 0.70002
# [4]	valid_0's auc: 0.701645
# [5]	valid_0's auc: 0.70601
# [6]	valid_0's auc: 0.707926
# [7]	valid_0's auc: 0.70945
# [8]	valid_0's auc: 0.710437
# [9]	valid_0's auc: 0.712047
# [10]	valid_0's auc: 0.713417
# [11]	valid_0's auc: 0.714648
# [12]	valid_0's auc: 0.715791
# [13]	valid_0's auc: 0.717431
# [14]	valid_0's auc: 0.718216
# [15]	valid_0's auc: 0.719381
# [16]	valid_0's auc: 0.720884
# [17]	valid_0's auc: 0.721617
# [18]	valid_0's auc: 0.722789
# [19]	valid_0's auc: 0.723307
# [20]	valid_0's auc: 0.72501
# [21]	valid_0's auc: 0.725721
# [22]	valid_0's auc: 0.727384
# [23]	valid_0's auc: 0.728268
# [24]	valid_0's auc: 0.72865
# [25]	valid_0's auc: 0.729141
# [26]	valid_0's auc: 0.729552
# [27]	valid_0's auc: 0.730459
# [28]	valid_0's auc: 0.731047
# [29]	valid_0's auc: 0.732472
# [30]	valid_0's auc: 0.732801
# [31]	valid_0's auc: 0.733166
# [32]	valid_0's auc: 0.734182
# [33]	valid_0's auc: 0.734472
# [34]	valid_0's auc: 0.735074
# [35]	valid_0's auc: 0.735738
# [36]	valid_0's auc: 0.735856
# [37]	valid_0's auc: 0.736747
# [38]	valid_0's auc: 0.737116
# [39]	valid_0's auc: 0.737297
# [40]	valid_0's auc: 0.73744
# [41]	valid_0's auc: 0.737789
# [42]	valid_0's auc: 0.737847
# [43]	valid_0's auc: 0.738086
# [44]	valid_0's auc: 0.738376
# [45]	valid_0's auc: 0.738509
# [46]	valid_0's auc: 0.739245
# [47]	valid_0's auc: 0.739561
# [48]	valid_0's auc: 0.739662
# [49]	valid_0's auc: 0.739738
# [50]	valid_0's auc: 0.739863
# [51]	valid_0's auc: 0.73994
# [52]	valid_0's auc: 0.740423
# [53]	valid_0's auc: 0.740466
# [54]	valid_0's auc: 0.740529
# [55]	valid_0's auc: 0.741066
# [56]	valid_0's auc: 0.74112
# [57]	valid_0's auc: 0.741285
# [58]	valid_0's auc: 0.741403
# [59]	valid_0's auc: 0.741591
# [60]	valid_0's auc: 0.741632
# [61]	valid_0's auc: 0.741989
# [62]	valid_0's auc: 0.742007
# [63]	valid_0's auc: 0.742152
# [64]	valid_0's auc: 0.742319
# [65]	valid_0's auc: 0.742416
# [66]	valid_0's auc: 0.742501
# [67]	valid_0's auc: 0.742604
# [68]	valid_0's auc: 0.742779
# [69]	valid_0's auc: 0.742934
# [70]	valid_0's auc: 0.742964
# [71]	valid_0's auc: 0.742945
# [72]	valid_0's auc: 0.74295
# [73]	valid_0's auc: 0.743061
# [74]	valid_0's auc: 0.743195
# [75]	valid_0's auc: 0.743198
# [76]	valid_0's auc: 0.743263
# [77]	valid_0's auc: 0.743313
# [78]	valid_0's auc: 0.743352
# [79]	valid_0's auc: 0.74336
# [80]	valid_0's auc: 0.743558
# [81]	valid_0's auc: 0.743577
# [82]	valid_0's auc: 0.74361
# [83]	valid_0's auc: 0.743618
# [84]	valid_0's auc: 0.743721
# [85]	valid_0's auc: 0.74376
# [86]	valid_0's auc: 0.743767
# [87]	valid_0's auc: 0.743845
# [88]	valid_0's auc: 0.743854
# [89]	valid_0's auc: 0.743855
# [90]	valid_0's auc: 0.743903
# [91]	valid_0's auc: 0.743952
# [92]	valid_0's auc: 0.743999
# [93]	valid_0's auc: 0.744033
# [94]	valid_0's auc: 0.744101
# [95]	valid_0's auc: 0.744146
# [96]	valid_0's auc: 0.744494
# [97]	valid_0's auc: 0.744516
# [98]	valid_0's auc: 0.744631
# [99]	valid_0's auc: 0.744678
# [100]	valid_0's auc: 0.74473
# [101]	valid_0's auc: 0.744713
# [102]	valid_0's auc: 0.744797
# [103]	valid_0's auc: 0.74485
# [104]	valid_0's auc: 0.744873
# [105]	valid_0's auc: 0.745315
# [106]	valid_0's auc: 0.745421
# [107]	valid_0's auc: 0.745417
# [108]	valid_0's auc: 0.745469
# [109]	valid_0's auc: 0.745479
# [110]	valid_0's auc: 0.745487
# [111]	valid_0's auc: 0.745863
# [112]	valid_0's auc: 0.745872
# [113]	valid_0's auc: 0.745915
# [114]	valid_0's auc: 0.745953
# [115]	valid_0's auc: 0.745919
# [116]	valid_0's auc: 0.745919
# [117]	valid_0's auc: 0.745969
# [118]	valid_0's auc: 0.74629
# [119]	valid_0's auc: 0.746331
# [120]	valid_0's auc: 0.74634
# [121]	valid_0's auc: 0.746324
# [122]	valid_0's auc: 0.746573
# [123]	valid_0's auc: 0.746602
# [124]	valid_0's auc: 0.746616
# [125]	valid_0's auc: 0.7466
# [126]	valid_0's auc: 0.746583
# [127]	valid_0's auc: 0.74663
# [128]	valid_0's auc: 0.746628
# [129]	valid_0's auc: 0.746623
# [130]	valid_0's auc: 0.746641
# [131]	valid_0's auc: 0.746647
# [132]	valid_0's auc: 0.746672
# [133]	valid_0's auc: 0.746648
# [134]	valid_0's auc: 0.746682
# [135]	valid_0's auc: 0.74671
# [136]	valid_0's auc: 0.746716
# [137]	valid_0's auc: 0.746698
# [138]	valid_0's auc: 0.746868
# [139]	valid_0's auc: 0.746899
# [140]	valid_0's auc: 0.746899
# [141]	valid_0's auc: 0.747047
# [142]	valid_0's auc: 0.747045
# [143]	valid_0's auc: 0.74705
# [144]	valid_0's auc: 0.747091
# [145]	valid_0's auc: 0.747102
# [146]	valid_0's auc: 0.7473
# [147]	valid_0's auc: 0.747294
# [148]	valid_0's auc: 0.747297
# [149]	valid_0's auc: 0.747358
# [150]	valid_0's auc: 0.747377
# [151]	valid_0's auc: 0.747398
# [152]	valid_0's auc: 0.747403
# [153]	valid_0's auc: 0.747418
# [154]	valid_0's auc: 0.747412
# [155]	valid_0's auc: 0.747415
# [156]	valid_0's auc: 0.74744
# [157]	valid_0's auc: 0.747471
# [158]	valid_0's auc: 0.747485
# [159]	valid_0's auc: 0.747484
# [160]	valid_0's auc: 0.747479
# [161]	valid_0's auc: 0.747515
# [162]	valid_0's auc: 0.747515
# [163]	valid_0's auc: 0.747519
# [164]	valid_0's auc: 0.747541
# [165]	valid_0's auc: 0.747549
# [166]	valid_0's auc: 0.747544
# [167]	valid_0's auc: 0.747538
# [168]	valid_0's auc: 0.747541
# [169]	valid_0's auc: 0.747579
# [170]	valid_0's auc: 0.747578
# [171]	valid_0's auc: 0.747591
# [172]	valid_0's auc: 0.747555
# [173]	valid_0's auc: 0.747529
# [174]	valid_0's auc: 0.74754
# [175]	valid_0's auc: 0.747513
# [176]	valid_0's auc: 0.747488
# [177]	valid_0's auc: 0.747513
# [178]	valid_0's auc: 0.747526
# [179]	valid_0's auc: 0.747511
# [180]	valid_0's auc: 0.747528
# [181]	valid_0's auc: 0.747544
# Early stopping, best iteration is:
# [171]	valid_0's auc: 0.747591
# CPU times: user 5.87 s, sys: 165 ms, total: 6.04 s
# Wall time: 6.46 s

# %% [markdown]
# A perfect classifier would have `auc = 1`, and random guessing would have `auc = 0.5`.

# %% [markdown]
# We've trained and validated the model to find the best iteration, now we can test the model.

# %%
from sklearn import metrics

ypred = bst.predict(test[feature_cols])
score = metrics.roc_auc_score(test['outcome'], ypred)

# %%
print('LightGBM Test AUC score: {:.4f}'.format(score))
# Out:
# LightGBM Test AUC score: 0.7476

# %% [markdown]
# We can compare to xgboost

# %%
# %%time
from xgboost import XGBRegressor
boost_model = XGBRegressor(n_estimators=500, eval_metric='auc')

boost_model.fit(train[feature_cols], train['outcome'], 
                early_stopping_rounds=10, 
                eval_set=[(valid[feature_cols], valid['outcome'])], verbose=True)
# Out:
# [00:54:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-auc:0.645159
# Will train until validation_0-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.653088
# [2]	validation_0-auc:0.654156
# [3]	validation_0-auc:0.654615
# [4]	validation_0-auc:0.65478
# [5]	validation_0-auc:0.658086
# [6]	validation_0-auc:0.658156
# [7]	validation_0-auc:0.661804
# [8]	validation_0-auc:0.662761
# [9]	validation_0-auc:0.665331
# [10]	validation_0-auc:0.665792
# [11]	validation_0-auc:0.667063
# [12]	validation_0-auc:0.668361
# [13]	validation_0-auc:0.67011
# [14]	validation_0-auc:0.670959
# [15]	validation_0-auc:0.673019
# [16]	validation_0-auc:0.673959
# [17]	validation_0-auc:0.675058
# [18]	validation_0-auc:0.675775
# [19]	validation_0-auc:0.677246
# [20]	validation_0-auc:0.679631
# [21]	validation_0-auc:0.680162
# [22]	validation_0-auc:0.680595
# [23]	validation_0-auc:0.681198
# [24]	validation_0-auc:0.681963
# [25]	validation_0-auc:0.683131
# [26]	validation_0-auc:0.684135
# [27]	validation_0-auc:0.684933
# [28]	validation_0-auc:0.68585
# [29]	validation_0-auc:0.687061
# [30]	validation_0-auc:0.688977
# [31]	validation_0-auc:0.689467
# [32]	validation_0-auc:0.690251
# [33]	validation_0-auc:0.690986
# [34]	validation_0-auc:0.692644
# [35]	validation_0-auc:0.693192
# [36]	validation_0-auc:0.693625
# [37]	validation_0-auc:0.694041
# [38]	validation_0-auc:0.694337
# [39]	validation_0-auc:0.695316
# [40]	validation_0-auc:0.695774
# [41]	validation_0-auc:0.696274
# [42]	validation_0-auc:0.696559
# [43]	validation_0-auc:0.696644
# [44]	validation_0-auc:0.696981
# [45]	validation_0-auc:0.697952
# [46]	validation_0-auc:0.698316
# [47]	validation_0-auc:0.698762
# [48]	validation_0-auc:0.699028
# [49]	validation_0-auc:0.69927
# [50]	validation_0-auc:0.699957
# [51]	validation_0-auc:0.700212
# [52]	validation_0-auc:0.7006
# [53]	validation_0-auc:0.701005
# [54]	validation_0-auc:0.701359
# [55]	validation_0-auc:0.70152
# [56]	validation_0-auc:0.701919
# [57]	validation_0-auc:0.702471
# [58]	validation_0-auc:0.702746
# [59]	validation_0-auc:0.702858
# [60]	validation_0-auc:0.703462
# [61]	validation_0-auc:0.703633
# [62]	validation_0-auc:0.703708
# [63]	validation_0-auc:0.703997
# [64]	validation_0-auc:0.70427
# [65]	validation_0-auc:0.704907
# [66]	validation_0-auc:0.705772
# [67]	validation_0-auc:0.706031
# [68]	validation_0-auc:0.706136
# [69]	validation_0-auc:0.70653
# [70]	validation_0-auc:0.706588
# [71]	validation_0-auc:0.706857
# [72]	validation_0-auc:0.707051
# [73]	validation_0-auc:0.707118
# [74]	validation_0-auc:0.707258
# [75]	validation_0-auc:0.707392
# [76]	validation_0-auc:0.70752
# [77]	validation_0-auc:0.707864
# [78]	validation_0-auc:0.70855
# [79]	validation_0-auc:0.708748
# [80]	validation_0-auc:0.709148
# [81]	validation_0-auc:0.709196
# [82]	validation_0-auc:0.709411
# [83]	validation_0-auc:0.709592
# [84]	validation_0-auc:0.70963
# [85]	validation_0-auc:0.710152
# [86]	validation_0-auc:0.71034
# [87]	validation_0-auc:0.710815
# [88]	validation_0-auc:0.711412
# [89]	validation_0-auc:0.711454
# [90]	validation_0-auc:0.71167
# [91]	validation_0-auc:0.711846
# [92]	validation_0-auc:0.711902
# [93]	validation_0-auc:0.711987
# [94]	validation_0-auc:0.712488
# [95]	validation_0-auc:0.712589
# [96]	validation_0-auc:0.712697
# [97]	validation_0-auc:0.712944
# [98]	validation_0-auc:0.712993
# [99]	validation_0-auc:0.713113
# [100]	validation_0-auc:0.713206
# [101]	validation_0-auc:0.713568
# [102]	validation_0-auc:0.713727
# [103]	validation_0-auc:0.713891
# [104]	validation_0-auc:0.713922
# [105]	validation_0-auc:0.714725
# [106]	validation_0-auc:0.714921
# [107]	validation_0-auc:0.714969
# [108]	validation_0-auc:0.71507
# [109]	validation_0-auc:0.715198
# [110]	validation_0-auc:0.715823
# [111]	validation_0-auc:0.715903
# [112]	validation_0-auc:0.716154
# [113]	validation_0-auc:0.716176
# [114]	validation_0-auc:0.716416
# [115]	validation_0-auc:0.716617
# [116]	validation_0-auc:0.71669
# [117]	validation_0-auc:0.716864
# [118]	validation_0-auc:0.716917
# [119]	validation_0-auc:0.716943
# [120]	validation_0-auc:0.717085
# [121]	validation_0-auc:0.717287
# [122]	validation_0-auc:0.717341
# [123]	validation_0-auc:0.7178
# [124]	validation_0-auc:0.71804
# [125]	validation_0-auc:0.718086
# [126]	validation_0-auc:0.718196
# [127]	validation_0-auc:0.71833
# [128]	validation_0-auc:0.718429
# [129]	validation_0-auc:0.718526
# [130]	validation_0-auc:0.71876
# [131]	validation_0-auc:0.718954
# [132]	validation_0-auc:0.71899
# [133]	validation_0-auc:0.71914
# [134]	validation_0-auc:0.719175
# [135]	validation_0-auc:0.71935
# [136]	validation_0-auc:0.719441
# [137]	validation_0-auc:0.719447
# [138]	validation_0-auc:0.719559
# [139]	validation_0-auc:0.719734
# [140]	validation_0-auc:0.719826
# [141]	validation_0-auc:0.719893
# [142]	validation_0-auc:0.720148
# [143]	validation_0-auc:0.720292
# [144]	validation_0-auc:0.720706
# [145]	validation_0-auc:0.721014
# [146]	validation_0-auc:0.721161
# [147]	validation_0-auc:0.721354
# [148]	validation_0-auc:0.721386
# [149]	validation_0-auc:0.721513
# [150]	validation_0-auc:0.721629
# [151]	validation_0-auc:0.721699
# [152]	validation_0-auc:0.721757
# [153]	validation_0-auc:0.721925
# [154]	validation_0-auc:0.721998
# [155]	validation_0-auc:0.722014
# [156]	validation_0-auc:0.722076
# [157]	validation_0-auc:0.722159
# [158]	validation_0-auc:0.722178
# [159]	validation_0-auc:0.72223
# [160]	validation_0-auc:0.722637
# [161]	validation_0-auc:0.722772
# [162]	validation_0-auc:0.722864
# [163]	validation_0-auc:0.723136
# [164]	validation_0-auc:0.723203
# [165]	validation_0-auc:0.723372
# [166]	validation_0-auc:0.723549
# [167]	validation_0-auc:0.723587
# [168]	validation_0-auc:0.723692
# [169]	validation_0-auc:0.72378
# [170]	validation_0-auc:0.723838
# [171]	validation_0-auc:0.723949
# [172]	validation_0-auc:0.724061
# [173]	validation_0-auc:0.724184
# [174]	validation_0-auc:0.72446
# [175]	validation_0-auc:0.724492
# [176]	validation_0-auc:0.724696
# [177]	validation_0-auc:0.72475
# [178]	validation_0-auc:0.724803
# [179]	validation_0-auc:0.725071
# [180]	validation_0-auc:0.725119
# [181]	validation_0-auc:0.725293
# [182]	validation_0-auc:0.725448
# [183]	validation_0-auc:0.725487
# [184]	validation_0-auc:0.725506
# [185]	validation_0-auc:0.725543
# [186]	validation_0-auc:0.72567
# [187]	validation_0-auc:0.725758
# [188]	validation_0-auc:0.725795
# [189]	validation_0-auc:0.725848
# [190]	validation_0-auc:0.726135
# [191]	validation_0-auc:0.726179
# [192]	validation_0-auc:0.726228
# [193]	validation_0-auc:0.726435
# [194]	validation_0-auc:0.726508
# [195]	validation_0-auc:0.726508
# [196]	validation_0-auc:0.726625
# [197]	validation_0-auc:0.726673
# [198]	validation_0-auc:0.726801
# [199]	validation_0-auc:0.726801
# [200]	validation_0-auc:0.726823
# [201]	validation_0-auc:0.726926
# [202]	validation_0-auc:0.727057
# [203]	validation_0-auc:0.727117
# [204]	validation_0-auc:0.727269
# [205]	validation_0-auc:0.727352
# [206]	validation_0-auc:0.727375
# [207]	validation_0-auc:0.727449
# [208]	validation_0-auc:0.727571
# [209]	validation_0-auc:0.72763
# [210]	validation_0-auc:0.727736
# [211]	validation_0-auc:0.727743
# [212]	validation_0-auc:0.727842
# [213]	validation_0-auc:0.727887
# [214]	validation_0-auc:0.727943
# [215]	validation_0-auc:0.728008
# [216]	validation_0-auc:0.728113
# [217]	validation_0-auc:0.72827
# [218]	validation_0-auc:0.728368
# [219]	validation_0-auc:0.728398
# [220]	validation_0-auc:0.728483
# [221]	validation_0-auc:0.728507
# [222]	validation_0-auc:0.728723
# [223]	validation_0-auc:0.728718
# [224]	validation_0-auc:0.72875
# [225]	validation_0-auc:0.728807
# [226]	validation_0-auc:0.728861
# [227]	validation_0-auc:0.72888
# [228]	validation_0-auc:0.728904
# [229]	validation_0-auc:0.729178
# [230]	validation_0-auc:0.729254
# [231]	validation_0-auc:0.729279
# [232]	validation_0-auc:0.729357
# [233]	validation_0-auc:0.729349
# [234]	validation_0-auc:0.729337
# [235]	validation_0-auc:0.729364
# [236]	validation_0-auc:0.729392
# [237]	validation_0-auc:0.729408
# [238]	validation_0-auc:0.729458
# [239]	validation_0-auc:0.729581
# [240]	validation_0-auc:0.729667
# [241]	validation_0-auc:0.729822
# [242]	validation_0-auc:0.729849
# [243]	validation_0-auc:0.730037
# [244]	validation_0-auc:0.730129
# [245]	validation_0-auc:0.730197
# [246]	validation_0-auc:0.73042
# [247]	validation_0-auc:0.730426
# [248]	validation_0-auc:0.730452
# [249]	validation_0-auc:0.730505
# [250]	validation_0-auc:0.730517
# [251]	validation_0-auc:0.730529
# [252]	validation_0-auc:0.730574
# [253]	validation_0-auc:0.730591
# [254]	validation_0-auc:0.730607
# [255]	validation_0-auc:0.730723
# [256]	validation_0-auc:0.73073
# [257]	validation_0-auc:0.730791
# [258]	validation_0-auc:0.730814
# [259]	validation_0-auc:0.730832
# [260]	validation_0-auc:0.73101
# [261]	validation_0-auc:0.731168
# [262]	validation_0-auc:0.731265
# [263]	validation_0-auc:0.73136
# [264]	validation_0-auc:0.731375
# [265]	validation_0-auc:0.73141
# [266]	validation_0-auc:0.731559
# [267]	validation_0-auc:0.731643
# [268]	validation_0-auc:0.731745
# [269]	validation_0-auc:0.731784
# [270]	validation_0-auc:0.731897
# [271]	validation_0-auc:0.731906
# [272]	validation_0-auc:0.7319
# [273]	validation_0-auc:0.731966
# [274]	validation_0-auc:0.732063
# [275]	validation_0-auc:0.732166
# [276]	validation_0-auc:0.732196
# [277]	validation_0-auc:0.732198
# [278]	validation_0-auc:0.732235
# [279]	validation_0-auc:0.732239
# [280]	validation_0-auc:0.732251
# [281]	validation_0-auc:0.732313
# [282]	validation_0-auc:0.732461
# [283]	validation_0-auc:0.732467
# [284]	validation_0-auc:0.732608
# [285]	validation_0-auc:0.732626
# [286]	validation_0-auc:0.732695
# [287]	validation_0-auc:0.732732
# [288]	validation_0-auc:0.732846
# [289]	validation_0-auc:0.732894
# [290]	validation_0-auc:0.732958
# [291]	validation_0-auc:0.733048
# [292]	validation_0-auc:0.733078
# [293]	validation_0-auc:0.733198
# [294]	validation_0-auc:0.733241
# [295]	validation_0-auc:0.733264
# [296]	validation_0-auc:0.73327
# [297]	validation_0-auc:0.733266
# [298]	validation_0-auc:0.73332
# [299]	validation_0-auc:0.733323
# [300]	validation_0-auc:0.733423
# [301]	validation_0-auc:0.733456
# [302]	validation_0-auc:0.733491
# [303]	validation_0-auc:0.733506
# [304]	validation_0-auc:0.733522
# [305]	validation_0-auc:0.733625
# [306]	validation_0-auc:0.733673
# [307]	validation_0-auc:0.733703
# [308]	validation_0-auc:0.73374
# [309]	validation_0-auc:0.733748
# [310]	validation_0-auc:0.733789
# [311]	validation_0-auc:0.733784
# [312]	validation_0-auc:0.733808
# [313]	validation_0-auc:0.733833
# [314]	validation_0-auc:0.73385
# [315]	validation_0-auc:0.733846
# [316]	validation_0-auc:0.73386
# [317]	validation_0-auc:0.733911
# [318]	validation_0-auc:0.733923
# [319]	validation_0-auc:0.734033
# [320]	validation_0-auc:0.734054
# [321]	validation_0-auc:0.734071
# [322]	validation_0-auc:0.734151
# [323]	validation_0-auc:0.734205
# [324]	validation_0-auc:0.734217
# [325]	validation_0-auc:0.734267
# [326]	validation_0-auc:0.734289
# [327]	validation_0-auc:0.734337
# [328]	validation_0-auc:0.734339
# [329]	validation_0-auc:0.73434
# [330]	validation_0-auc:0.734372
# [331]	validation_0-auc:0.734373
# [332]	validation_0-auc:0.734405
# [333]	validation_0-auc:0.73446
# [334]	validation_0-auc:0.734472
# [335]	validation_0-auc:0.734535
# [336]	validation_0-auc:0.73459
# [337]	validation_0-auc:0.734616
# [338]	validation_0-auc:0.734638
# [339]	validation_0-auc:0.734718
# [340]	validation_0-auc:0.734732
# [341]	validation_0-auc:0.73473
# [342]	validation_0-auc:0.734804
# [343]	validation_0-auc:0.734799
# [344]	validation_0-auc:0.734819
# [345]	validation_0-auc:0.73486
# [346]	validation_0-auc:0.734871
# [347]	validation_0-auc:0.734893
# [348]	validation_0-auc:0.734921
# [349]	validation_0-auc:0.734966
# [350]	validation_0-auc:0.735045
# [351]	validation_0-auc:0.735182
# [352]	validation_0-auc:0.73524
# [353]	validation_0-auc:0.735239
# [354]	validation_0-auc:0.73525
# [355]	validation_0-auc:0.735247
# [356]	validation_0-auc:0.735273
# [357]	validation_0-auc:0.735284
# [358]	validation_0-auc:0.735355
# [359]	validation_0-auc:0.735383
# [360]	validation_0-auc:0.735388
# [361]	validation_0-auc:0.735431
# [362]	validation_0-auc:0.735447
# [363]	validation_0-auc:0.735481
# [364]	validation_0-auc:0.735516
# [365]	validation_0-auc:0.735523
# [366]	validation_0-auc:0.735532
# [367]	validation_0-auc:0.735551
# [368]	validation_0-auc:0.735617
# [369]	validation_0-auc:0.735633
# [370]	validation_0-auc:0.73568
# [371]	validation_0-auc:0.735698
# [372]	validation_0-auc:0.7357
# [373]	validation_0-auc:0.735735
# [374]	validation_0-auc:0.735743
# [375]	validation_0-auc:0.73585
# [376]	validation_0-auc:0.735851
# [377]	validation_0-auc:0.735855
# [378]	validation_0-auc:0.735901
# [379]	validation_0-auc:0.735903
# [380]	validation_0-auc:0.735923
# [381]	validation_0-auc:0.735924
# [382]	validation_0-auc:0.735928
# [383]	validation_0-auc:0.735983
# [384]	validation_0-auc:0.736028
# [385]	validation_0-auc:0.736037
# [386]	validation_0-auc:0.736051
# [387]	validation_0-auc:0.736083
# [388]	validation_0-auc:0.736098
# [389]	validation_0-auc:0.736095
# [390]	validation_0-auc:0.736095
# [391]	validation_0-auc:0.736176
# [392]	validation_0-auc:0.736199
# [393]	validation_0-auc:0.736247
# [394]	validation_0-auc:0.736274
# [395]	validation_0-auc:0.736277
# [396]	validation_0-auc:0.736274
# [397]	validation_0-auc:0.736278
# [398]	validation_0-auc:0.736309
# [399]	validation_0-auc:0.736344
# [400]	validation_0-auc:0.736416
# [401]	validation_0-auc:0.736415
# [402]	validation_0-auc:0.736417
# [403]	validation_0-auc:0.736494
# [404]	validation_0-auc:0.736536
# [405]	validation_0-auc:0.736544
# [406]	validation_0-auc:0.736627
# [407]	validation_0-auc:0.736616
# [408]	validation_0-auc:0.73666
# [409]	validation_0-auc:0.736722
# [410]	validation_0-auc:0.73673
# [411]	validation_0-auc:0.736756
# [412]	validation_0-auc:0.736764
# [413]	validation_0-auc:0.736764
# [414]	validation_0-auc:0.736784
# [415]	validation_0-auc:0.736896
# [416]	validation_0-auc:0.736948
# [417]	validation_0-auc:0.736948
# [418]	validation_0-auc:0.736977
# [419]	validation_0-auc:0.736976
# [420]	validation_0-auc:0.737015
# [421]	validation_0-auc:0.737067
# [422]	validation_0-auc:0.737101
# [423]	validation_0-auc:0.737103
# [424]	validation_0-auc:0.737098
# [425]	validation_0-auc:0.737141
# [426]	validation_0-auc:0.737151
# [427]	validation_0-auc:0.737151
# [428]	validation_0-auc:0.737165
# [429]	validation_0-auc:0.737167
# [430]	validation_0-auc:0.737205
# [431]	validation_0-auc:0.73722
# [432]	validation_0-auc:0.737239
# [433]	validation_0-auc:0.737281
# [434]	validation_0-auc:0.737311
# [435]	validation_0-auc:0.737325
# [436]	validation_0-auc:0.737316
# [437]	validation_0-auc:0.737315
# [438]	validation_0-auc:0.737314
# [439]	validation_0-auc:0.737423
# [440]	validation_0-auc:0.737437
# [441]	validation_0-auc:0.737442
# [442]	validation_0-auc:0.737459
# [443]	validation_0-auc:0.737449
# [444]	validation_0-auc:0.737453
# [445]	validation_0-auc:0.737504
# [446]	validation_0-auc:0.737505
# [447]	validation_0-auc:0.737585
# [448]	validation_0-auc:0.737582
# [449]	validation_0-auc:0.737638
# [450]	validation_0-auc:0.737652
# [451]	validation_0-auc:0.737662
# [452]	validation_0-auc:0.737667
# [453]	validation_0-auc:0.737674
# [454]	validation_0-auc:0.737678
# [455]	validation_0-auc:0.73771
# [456]	validation_0-auc:0.737723
# [457]	validation_0-auc:0.737725
# [458]	validation_0-auc:0.737753
# [459]	validation_0-auc:0.737789
# [460]	validation_0-auc:0.737801
# [461]	validation_0-auc:0.737834
# [462]	validation_0-auc:0.737829
# [463]	validation_0-auc:0.737849
# [464]	validation_0-auc:0.737886
# [465]	validation_0-auc:0.737897
# [466]	validation_0-auc:0.737913
# [467]	validation_0-auc:0.737933
# [468]	validation_0-auc:0.73797
# [469]	validation_0-auc:0.738023
# [470]	validation_0-auc:0.738044
# [471]	validation_0-auc:0.738039
# [472]	validation_0-auc:0.73811
# [473]	validation_0-auc:0.738134
# [474]	validation_0-auc:0.738141
# [475]	validation_0-auc:0.738136
# [476]	validation_0-auc:0.73814
# [477]	validation_0-auc:0.73815
# [478]	validation_0-auc:0.738191
# [479]	validation_0-auc:0.738219
# [480]	validation_0-auc:0.738263
# [481]	validation_0-auc:0.738297
# [482]	validation_0-auc:0.738346
# [483]	validation_0-auc:0.738401
# [484]	validation_0-auc:0.738439
# [485]	validation_0-auc:0.738441
# [486]	validation_0-auc:0.738455
# [487]	validation_0-auc:0.738486
# [488]	validation_0-auc:0.738494
# [489]	validation_0-auc:0.738504
# [490]	validation_0-auc:0.738529
# [491]	validation_0-auc:0.738549
# [492]	validation_0-auc:0.738551
# [493]	validation_0-auc:0.738559
# [494]	validation_0-auc:0.738566
# [495]	validation_0-auc:0.738569
# [496]	validation_0-auc:0.738571
# [497]	validation_0-auc:0.738589
# [498]	validation_0-auc:0.738598
# [499]	validation_0-auc:0.738594
# CPU times: user 1min 37s, sys: 1.09 s, total: 1min 38s
# Wall time: 1min 42s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eval_metric='auc', gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
boost_pred = boost_model.predict(test[feature_cols])

# %%
boost_score = metrics.roc_auc_score(test['outcome'], boost_pred)

# %%
print('XGBoost Test AUC score: {:.4f}'.format(boost_score))
# Out:
# XGBoost Test AUC score: 0.7397

# %% [markdown]
# The `XGBoost` model performed ever so slightly worse than `LightGBM`, and took 1 min 42 seconds as compared to `LightGBM`'s mere 6 seconds.
